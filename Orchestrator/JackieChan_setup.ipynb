# %%
#drive mount
#make sure you click the "Software Engineering" folder and select "add a shortcut to drive"

#you can also click the side panel on the left, click the "mount drive" and your drive should be mounted

from google.colab import drive
drive.mount("/content/drive", force_remount=True)

#run this, click the link and enter the authorization code
# Out:
# Mounted at /content/drive

# %%
#in this cell, it deplays all the file in "Software_Engineering" folder

# !ls "/content/drive/MyDrive/Software_Engineering"
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# CodeRelated  Documentation

# %%
# for running the code inside the shared folder
# %cd is for changing the working directory, %ls would print all the file inside

ROOT_PATH = '/content/drive/MyDrive/Software_Engineering'
# %cd $ROOT_PATH
# %ls $ROOT_PATH
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-23-ab77274efd0f>", line 5, in <module>
#     get_ipython().magic('cd $ROOT_PATH')
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-84>", line 2, in cd
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
# verifying the current working directory
# !pwd
# Out:
# /content/drive/MyDrive/Software_Engineering

# %%
# %ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ls: cannot open directory '.': Transport endpoint is not connected

# %%
pip install requests

# %%
#test
#this cell is only for testing whether you can run the test files

#when you need to write the file name, try to wirte the path instead of just the name
#on the side panel, right click the file and you can "copy path" your file

import requests

#either one or both should work

new = !python /content/drive/MyDrive/Software_Engineering/JurasicTest6.py
new1 = !python JurasicTest6.py

print(new[0])
print(new[1])
print(new1[0])
print(new1[1])
# Out:
# python3: can't open file '/content/drive/MyDrive/Software_Engineering/JurasicTest6.py': [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-b7c1f4208c01> in <module>()
#      13
#      14 print(new[0])
# ---> 15 print(new[1])
#      16 print(new1[0])
#      17 print(new1[1])
#
# IndexError: list index out of range

# %%
#This is the code to interact with the API of ai21 (Jurasic model). You can change the prompt variable to ask the api different questions. Make sure it is a string, because otherwise it will not work.
#As stated in whatsapp it only does completion and not Q and A type awnsering (pretty sure we can change it, but I'm not sure how yet).


import requests
import json

#prompt = "Q: In how many movies has Jackie Chan starred? A: Jackie chan has starred in 131 movies, isn't that a lot! --- Q: What is the name of the Jackie Chan and Chris tucker action-comedy movie where they are in china? A: It is Rush Hour 2, which is an amazing movie --- Q: When was The Karate Kid released? A: The Karate Kid was released in 2010. --- Q:How many Rush Hour movies were made? A:   "
prompt = "In how many movies has Jackie Chan starred? --- Jackie chan has starred in 131 movies, isn't that a lot! ---   What is the movie with jackie chan and the panda who does kung fu?--- "


new =requests.post(
    "https://api.ai21.com/studio/v1/j1-jumbo/complete",   #If we want to use the other model we can change the "j1-jumbo" in the url to "j1-large".
    headers={"Authorization": "Bearer vc7KLlGzEjqrbyKuJ5lmJXejJCeBVfE2"}, #Don't change this. The bunch of letters (next to Bearer) is my API authorization code. If we ever go over limit we can change it to one of yours.
    json={
        "prompt": prompt, 
        "numResults": 1, #This is the number of completions (outputs) it will give. Lets keep this at 1 for now :)
        "maxTokens": 32, #This is the Maximum number of tokens generated. If we increase this, the awnsers will get more and more crazy.
        "stopSequences": ["---"], #We can set a stop sequence to make sure it only returns 1 sentence. It will basically keep outputting until the stop sequence is met or the max tokens are reached.
        "topKReturn": 0,#Returns the top other results. When put to >0 it will give other responses. Best to keep this at 0 for now too.
        "temperature": 0.4 #Modifies the distribution from which tokens are sampled. Basically when increased to above 0 it will take some outputs which have a lower probability of being chosen.
    }
)

data = new.json()

for a in data["completions"]:
    newdata = a

    
print(newdata["data"]["text"])
# Out:
#
#
# 2 Answers
# 2
#
# Jackie Chan has starred in 131 movies, isn't that a lot!
#
# Yes, it is.
#
# What is the movie
